# %% [markdown]
# <a href="https://colab.research.google.com/github/prasadLgit/ImageAnalyzer/blob/main/ImazeAnalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.genai import types

from google.colab import userdata
api_key = userdata.get("API_KEY")

client = genai.Client(api_key = api_key)

def process_image(path):
  image_type = path.split(".")[-1]
  with open(path, "rb") as f:
     image_bytes = f.read()

  image_part = types.Part.from_bytes(
      data = image_bytes,
      mime_type = f"image/{image_type}"
  )

  response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=[
        """Analyze this artwork image and provide:
        1. Possible artist (if recognizable)
        2. Artistic style
        3. Short explanation of the artwork
        """,
        image_part
    ]
  )

  return response.text

# %% [markdown]
# ```markdown
# The `imageanalyzer` function takes an image path as input and uses the Gemini API to analyze the artwork. It extracts the following information:
#
# 1.  **Possible Artist:** Identifies the potential artist if recognizable.
# 2.  **Artistic Style:** Determines the artistic style of the artwork.
# 3.  **Short Explanation:** Provides a brief description and explanation of the artwork.
# ```

# %%
from PIL import Image as PILImage
import os

image = "DaVinci.jfif"
output_image_path = "DaVinci.jpeg"

with PILImage.open(image) as img:
    img.save(output_image_path, "jpeg")

from IPython.display import Image, display
display(Image(output_image_path))

# %%
print(process_image(output_image_path))
# Out:
# Here's an analysis of the artwork:
#
# 1.  **Possible artist:** Leonardo da Vinci. This painting is instantly recognizable as the Mona Lisa, his most famous work.
#
# 2.  **Artistic style:** High Renaissance. This style is characterized by a focus on realism, idealization of human form, harmonious composition, and the use of techniques like *sfumato* and *chiaroscuro*.
#
# 3.  **Short explanation of the artwork:** The Mona Lisa is a half-length portrait of a woman, believed to be Lisa del Giocondo, set against an enigmatic, atmospheric landscape. The painting is renowned for its subtle and captivating smile, the masterful use of *sfumato* (a technique of soft, hazy transitions between colors and tones, particularly visible around the eyes and mouth), and the psychological depth conveyed in the sitter's gaze. The composition, with its balanced yet dynamic elements, and the detailed rendering of fabric and the natural world, exemplify the peak of Renaissance artistic achievement.

# %%
image = "VincentvanGoghPainting.jfif"
output_image_path = "VincentvanGoghPainting.jpeg"

with PILImage.open(image) as img:
    img.save(output_image_path, "jpeg")

from IPython.display import Image, display
display(Image(output_image_path))

# %%
print(process_image(output_image_path))
# Out:
# Here's an analysis of the artwork:
#
# 1.  **Possible Artist:** Vincent van Gogh
#
# 2.  **Artistic Style:** Post-Impressionism, characterized by its expressive brushwork, vibrant colors, and emotional intensity. Specifically, it aligns with Van Gogh's late period style, often referred to as his "Arles" or "Auvers-sur-Oise" period.
#
# ...
